# %%
import requests
from bs4 import BeautifulSoup as BS
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import ast
import time
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# # Νεα Δημοκρατια

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"}

# %%
response = requests.get("https://www.news247.gr/nea-dimokratia")
nea_doc = BeautifulSoup(response.text, 'html.parser')

# %%
headlines = nea_doc.find_all('h2')

for headline in headlines:
    print(headline.text)
# Out:
#                 ΜΕ ΜΙΑ ΜΑΤΙΑ
#
#
#                             Χαλκιδική: Συγκλονιστικές περιγραφές για τον 30χρονο τουρίστα - Πώς επιβίωσε 18 ώρες στο νερό
#
#
#
#                             Θερινές εκπτώσεις 2022: Ξεκινούν τη Δευτέρα - Πόσο θα διαρκέσουν
#
#
#
#                             Κακοκαιρία: Σε κατάσταση έκτακτης ανάγκης η Σκύρος - Προβλήματα σε Σκιάθο και Θάσο
#
#
# Ειδήσεις και πληροφορίες σχετικά με το κόμμα 'Νέα Δημοκρατία' (ΝΔ), επικεφαλής του οποίου είναι ο Κυριάκος Μητσοτάκης.
#
#
# Μια ανασκόπηση όσων διαδραματίστηκαν την εβδομάδα που πέρασε στη Βουλή
#
#
# Ασκήσεις μικροπολιτικής ετοιμότητος
#
#
# "Μύλος": ΔΑΠ διαψεύδει ΔΑΠ Νομικής για την ανακοίνωση κατά Κεραμέως
#
#
# Το ρίσκο Μητσοτάκη και νέα σενάρια ανασχηματισμού
#
#
# ΔΑΠ κατά Κεραμέως για τις φοιτητικές εκλογές: "Εμείς στα αμφιθέατρα, αυτοί στα Υπουργεία"
#
#
# Ακόμα πιο ξεκάθαρος ο Μητσοτάκης - "Δεν πάω σε πρόωρες εκλογές"
#
#
# Τι κρύβει το "εκλογές το 2023" του Μητσοτάκη
#
#
# ...

# %%
#nea_doc

# %%
links = nea_doc.select("h2 a") 
#links

# %%
urls = [link['href'] for link in links]
#urls

# %%
titles = [link.text for link in links]
#titles

# %%
scraped_links = []
titles = []
counter = 0
base_url = "https://www.news247.gr/nea-dimokratia?pages="
for i in range(1,50):
    url = base_url + str(i)
    #print(url)
    page = requests.get(url, headers = headers)
    s = BeautifulSoup(page.content, 'html.parser')
    #print(s)
    links = s.select("h2 a")
    links = set(links)
    
    url = [link['href'] for link in links]
    
    #title = [link.text for link in links]
    
    
    print(url)

    for l in url:
        link = l
        print(l)
        scraped_links.append(l)


    
    # Τυπώνει το νούμερο των links που είναι scraped
print(len(scraped_links)) 

nea_links = (set(scraped_links))
# Out:
# ['https://www.news247.gr/politiki/mitsotakis-oi-ekloges-tha-ginoyn-sto-telos-tis-tetraetias.9688563.html', 'https://www.news247.gr/politiki/antisyriza-metopo-a-la-2015-kai-proeklogiko-liftingk-stin-kyvernisi.9679526.html', 'https://www.news247.gr/politiki/dap-kata-kerameos-gia-tis-foititikes-ekloges-emeis-sta-amfitheatra-aytoi-sta-ypoyrgeia.9689996.html', 'https://www.news247.gr/gnomes/giwrgos-karelias/novartis-i-ypothesi-poy-exeytelise-politikoys-kai-mme.9685646.html', 'https://www.news247.gr/politiki/o-mitsotakis-epicheirei-na-vgei-sto-kke-ex-aristeron-alla-thymizei-thatser.9688170.html', 'https://www.news247.gr/sunday-edition/oi-teleytaies-pinelies-sta-psifodeltia-tis-nd-ziteitai-marantona-gia-to-epikrateias.9684139.html', 'https://www.news247.gr/politiki/i-kyvernisi-fovatai-tin-orgi-ton-syntaxioychon.9686724.html', 'https://www.news247.gr/koinonia/karamanlis-erga-me-akalyptes-epitages-den-tha-akoysoyn-apo-emas-pote-oi-ellines-polites.9680868.html', 'https://www.news247.gr/politik
# ...

# %%
#nea_links

# %%
len(nea_links)
# Out:
# 1963

# %% [markdown]
# # Δημιουργία DataFrame

# %%
nea = pd.DataFrame(nea_links, columns= ['url'])
#nea

# %%
nea.to_csv("nea.csv", index=False)
nea = pd.read_csv('nea.csv')
nea
# Out:
#                                                     url
# 0     https://www.news247.gr/politiki/nd-apantisi-st...
# 1     https://www.news247.gr/politiki/achtsiogloy-mi...
# 2     https://www.news247.gr/politiki/o-mitsotakis-e...
# 3     https://www.news247.gr/politiki/piges-tis-nd-t...
# 4     https://www.news247.gr/media/eleytherotypia-ky...
# ...                                                 ...
# 1958  https://www.news247.gr/politiki/kakokairia-mid...
# 1959  https://www.news247.gr/gnomes/giannhs-trianths...
# 1960  https://www.news247.gr/gnomes/manos-xwrianopoy...
# 1961  https://www.news247.gr/paideia/to-eidiko-katas...
# 1962  https://www.news247.gr/gnomes/viky-samara/poio...
#
# [1963 rows x 1 columns]

# %%
urls = nea['url'].tolist()
urls[0:100]
# Out:
# ['https://www.news247.gr/politiki/nd-apantisi-ston-syriza-me-ta-fek-proagogis-toy-archigoy-tis-pyrosvestikis.9322672.html',
#  'https://www.news247.gr/politiki/achtsiogloy-mitsotakis-kai-vroytsis-organosan-mia-akomi-epikoinoniaki-fiesta.7685261.html',
#  'https://www.news247.gr/politiki/o-mitsotakis-epicheirei-syspeirosi-tis-nd-meso-toyrkias.9662486.html',
#  'https://www.news247.gr/politiki/piges-tis-nd-ta-syrizonomics-toy-k-tsipra.7501718.html',
#  'https://www.news247.gr/media/eleytherotypia-kyvernisi-kai-antipoliteysi-ethesan-to-zitima-tis-apozimiosis-stin-eet.7667387.html',
#  'https://www.news247.gr/politiki/dimoskopisi-mrb-proti-me-diafora-19-7-i-nd.7645217.html',
#  'https://www.news247.gr/politiki/syriza-o-mitsotakis-den-tolmise-na-apopempsei-ton-diamatari.7544529.html',
#  'https://www.news247.gr/politiki/nd-toyristas-kai-stis-diadiloseis-o-tsipras.7534293.html',
# ...

# %%
len(urls)
# Out:
# 1963

# %%
response = requests.get("https://www.news247.gr/nea-dimokratia", headers=headers)

doc = BeautifulSoup(response.text)

# %%
#urls

# %%
from urllib.request import urlopen, Request
# %matplotlib inline
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import numpy as np

# %%
nea = pd.DataFrame(columns = ['Title', 'created_at', 'URL', 'text', 'About_text', 'About_URL'])

# %%
titles = []#check
links = []#check
authors = [] # authors don't exist
dates = []#check
descs = []#check
abouts_text = []#check
abouts_URL = []#check


for i in range(1,50):
  my_url = 'https://www.news247.gr/nea-dimokratia?pages='+str(i)
  req = Request(my_url,headers={'User-Agent': 'Mozilla/5.0'})
  # print(my_url)
  raw_html = urlopen(req).read()
  news = BeautifulSoup(raw_html, "html.parser")


  titles_soup = news.find_all("h2", {"class": "article__title bold"})

  # links = news.find_all("h2", {"class": "article__title bold"})
  for title in titles_soup:
    links.append(title.find('a')['href'])
    titles.append((title.text).replace('\n',''))

  abouts_soup = news.find_all("div", {"class": "article__summary"})
  for about in abouts_soup:
    info = (about.text).splitlines()
    # print(info)
    abouts_text.append(info[1])

    descs.append(info[2])

    dates.append(info[3])

    abouts_URL.append(about.find('a')['href'])

print(len(titles))
print(len(links))
print(len(dates))
print(len(descs))
print(len(abouts_text))
print(len(abouts_URL))
# Out:
# 1960
# 1960
# 1960
# 1960
# 1960
# 1960

# %%
# nea = pd.DataFrame(columns = ['Title', 'created_at', 'URL', 'text', 'About_text', 'About_URL'])

for i in range(0, len(titles)):
  nea = nea.append({'Title' : titles[i], 'created_at' : dates[i], 'URL' : links[i], 'text' : descs[i], 'About_text' : abouts_text[i], 'About_URL' : abouts_URL[i]}, ignore_index=True)

# %%
nea
# Out:
#                                                   Title  \
# 0     Μια ανασκόπηση όσων διαδραματίστηκαν την εβδομ...
# 1                   Ασκήσεις μικροπολιτικής ετοιμότητος
# 2     "Μύλος": ΔΑΠ διαψεύδει ΔΑΠ Νομικής για την ανα...
# 3     Το ρίσκο Μητσοτάκη και νέα σενάρια ανασχηματισμού
# 4     ΔΑΠ κατά Κεραμέως για τις φοιτητικές εκλογές: ...
# ...                                                 ...
# 1955  Η επικοινωνιακή "τριάδα" του Μητσοτάκη και το ...
# 1956  Η ακτινογραφία της κυβέρνησης Μητσοτάκη: Τεχνο...
# 1957  Τα νέα πρόσωπα στις κοινοβουλευτικές ομάδες τη...
# 1958  Συγχαρητήριο μήνυμα State Department στη νέα κ...
# 1959  Γιώργος Ζαββός, ο νέος Υφυπουργός αρμόδιος για...
#
#                  created_at  \
# 0     09 Ιουλίου 2022 08:17
# 1     08 Ιουλίου 2022 11:54
# 2     08 Ιουλίου 2022 09:41
# 3     08 Ιουλίου 2022 06:15
# 4     07 Ιουλίου 2022 22:01
# ...                     ...
# 1955  09 Ιουλίου 2019 07:17
# 1956  09 Ιουλίου 2019 07:11
# ...

# %%
nea.dtypes
# Out:
# Title         object
# created_at    object
# URL           object
# text          object
# About_text    object
# About_URL     object
# dtype: object

# %%
nea_doc = nea[['Title','created_at', 'URL', 'text', 'About_text',  ]]
nea_doc
# Out:
#                                                   Title  \
# 0     Μια ανασκόπηση όσων διαδραματίστηκαν την εβδομ...
# 1                   Ασκήσεις μικροπολιτικής ετοιμότητος
# 2     "Μύλος": ΔΑΠ διαψεύδει ΔΑΠ Νομικής για την ανα...
# 3     Το ρίσκο Μητσοτάκη και νέα σενάρια ανασχηματισμού
# 4     ΔΑΠ κατά Κεραμέως για τις φοιτητικές εκλογές: ...
# ...                                                 ...
# 1955  Η επικοινωνιακή "τριάδα" του Μητσοτάκη και το ...
# 1956  Η ακτινογραφία της κυβέρνησης Μητσοτάκη: Τεχνο...
# 1957  Τα νέα πρόσωπα στις κοινοβουλευτικές ομάδες τη...
# 1958  Συγχαρητήριο μήνυμα State Department στη νέα κ...
# 1959  Γιώργος Ζαββός, ο νέος Υφυπουργός αρμόδιος για...
#
#                  created_at  \
# 0     09 Ιουλίου 2022 08:17
# 1     08 Ιουλίου 2022 11:54
# 2     08 Ιουλίου 2022 09:41
# 3     08 Ιουλίου 2022 06:15
# 4     07 Ιουλίου 2022 22:01
# ...                     ...
# 1955  09 Ιουλίου 2019 07:17
# 1956  09 Ιουλίου 2019 07:11
# ...

# %%
# def get_page(page_number):
#     headers = {
#         "accept": "application/json",
#         "accept-language": "en-US,en;q=0.9,el;q=0.8",
#         "cache-control": "no-cache",
#         "content-type": "application/json; charset=UTF-8",
#         "pragma": "no-cache",
#         "sec-ch-ua": "\" Not;A Brand\";v=\"99\", \"Google Chrome\";v=\"91\", \"Chromium\";v=\"91\"",
#         "sec-ch-ua-mobile": "?0",
#         "sec-fetch-dest": "empty",
#         "sec-fetch-mode": "cors",
#         "sec-fetch-site": "same-origin",
#         "x-requested-with": "XMLHttpRequest",
#     }
#     req = requests.get("https://www.news247.gr/nea-dimokratia",headers=headers,json= {"pages":page_number})
#     return req

# %%
# def get_articles(content):
#     html = BS(content, features='html.parser')
#     articles = html.find_all('article',{"class": "article_left"})
#     return articles

# def parse_article(article):
#     href = article.find('a')['href']
#     title = article.find('a')['title']
#     leadtext = article.find('p',{"class": "article__leadtext"}).text
#     tag = article.find('a',{"class": "article__tag_section"}).text
#     datetime = article.find('time').text
#     datum = {
#         'Title': title,
#         'Href' : href,
#         'Leadtext':leadtext,
#         'Tag':tag,
#         'Datetime': datetime
#     }
#     return datum
    
# count = 0
# page_count = 1
# data = []
# while(count < 1960):
#     page = get_page(page_count)
#     page_count = page_count + 1
#     articles = get_articles(page.content)
#     for article in articles:
#         datum = parse_article(article)
#         data.append(datum)
#         count = count + 1
# nea_doc = pd.DataFrame(data)
# nea_doc

# %%
#nea_doc.dtypes

# %%
nea_doc = nea_doc.rename(columns = {'created_at':'Datetime', 'About_text':'Tag', 'URL':'Href', 'text':'Leadtext'})

# %%
nea_doc.dtypes
# Out:
# Title       object
# Datetime    object
# Href        object
# Leadtext    object
# Tag         object
# dtype: object

# %%
nea_doc.iloc[0,1].split(' ')[2]
# Out:
# '2022'

# %%
nea_doc.Datetime
# Out:
# 0       09 Ιουλίου 2022 08:17
# 1       08 Ιουλίου 2022 11:54
# 2       08 Ιουλίου 2022 09:41
# 3       08 Ιουλίου 2022 06:15
# 4       07 Ιουλίου 2022 22:01
#                 ...
# 1955    09 Ιουλίου 2019 07:17
# 1956    09 Ιουλίου 2019 07:11
# 1957    08 Ιουλίου 2019 23:34
# 1958    08 Ιουλίου 2019 22:16
# 1959    08 Ιουλίου 2019 21:15
# Name: Datetime, Length: 1960, dtype: object

# %%
months = {
  'Ιανουαρίου' : '01',
  'Φεβρουαρίου' : '02', 
  'Μαρτίου' : '03',
  'Απριλίου' : '04',
  'Μαΐου' : '05',
  'Ιουνίου': '06',
  'Ιουλίου' : '07',
  'Αυγούστου' : '08',
  'Σεπτεμβρίου' : '09',
  'Οκτωβρίου' : '10',
  'Νοεμβρίου' : '11',
  'Δεκεμβρίου' : '12',
     
}
def split_date(num, date):

  try:
    wanted = date.split(' ')[num]
    if (not any(str.isdigit(c) for c in wanted)):
      if num == 0:
        wanted = '10'
      elif num == 1:
        if wanted not in months:
          wanted = "Ιουλίου"
      elif num == 2:
        wanted = '2022'
      elif num == 3:
        wanted = '18:00'
  except:
    if num == 0:
      wanted = '10'
    elif num == 1:
      wanted = 'Ιουλίου'
    elif num == 2:
      wanted = '2022'
    elif num == 3:
      wanted = '18:00'

  return wanted

# %%
nea_doc
# Out:
#                                                   Title  \
# 0     Μια ανασκόπηση όσων διαδραματίστηκαν την εβδομ...
# 1                   Ασκήσεις μικροπολιτικής ετοιμότητος
# 2     "Μύλος": ΔΑΠ διαψεύδει ΔΑΠ Νομικής για την ανα...
# 3     Το ρίσκο Μητσοτάκη και νέα σενάρια ανασχηματισμού
# 4     ΔΑΠ κατά Κεραμέως για τις φοιτητικές εκλογές: ...
# ...                                                 ...
# 1955  Η επικοινωνιακή "τριάδα" του Μητσοτάκη και το ...
# 1956  Η ακτινογραφία της κυβέρνησης Μητσοτάκη: Τεχνο...
# 1957  Τα νέα πρόσωπα στις κοινοβουλευτικές ομάδες τη...
# 1958  Συγχαρητήριο μήνυμα State Department στη νέα κ...
# 1959  Γιώργος Ζαββός, ο νέος Υφυπουργός αρμόδιος για...
#
#                    Datetime  \
# 0     09 Ιουλίου 2022 08:17
# 1     08 Ιουλίου 2022 11:54
# 2     08 Ιουλίου 2022 09:41
# 3     08 Ιουλίου 2022 06:15
# 4     07 Ιουλίου 2022 22:01
# ...                     ...
# 1955  09 Ιουλίου 2019 07:17
# 1956  09 Ιουλίου 2019 07:11
# ...

# %%
# nea_doc[['Day', 'Month', 'Year', 'Time']] = nea_doc['Datetime'].str.split(' ', expand=True)
nea_doc['Year'] = nea_doc.Datetime.apply(lambda dt: split_date(2,dt))
nea_doc['Month'] = nea_doc.Datetime.apply(lambda dt: split_date(1,dt))
nea_doc['Day'] = nea_doc.Datetime.apply(lambda dt: split_date(0,dt))
nea_doc['Time'] = nea_doc.Datetime.apply(lambda dt: split_date(3,dt))


nea_doc['Date'] = nea_doc.apply(lambda row: f'{months[row.Month]}/{row.Day}/{row.Year} {row.Time}', axis='columns',result_type='expand')
nea_doc['Date'] = pd.to_datetime(nea_doc['Date'])
nea_doc
# Out:
#                                                   Title  \
# 0     Μια ανασκόπηση όσων διαδραματίστηκαν την εβδομ...
# 1                   Ασκήσεις μικροπολιτικής ετοιμότητος
# 2     "Μύλος": ΔΑΠ διαψεύδει ΔΑΠ Νομικής για την ανα...
# 3     Το ρίσκο Μητσοτάκη και νέα σενάρια ανασχηματισμού
# 4     ΔΑΠ κατά Κεραμέως για τις φοιτητικές εκλογές: ...
# ...                                                 ...
# 1955  Η επικοινωνιακή "τριάδα" του Μητσοτάκη και το ...
# 1956  Η ακτινογραφία της κυβέρνησης Μητσοτάκη: Τεχνο...
# 1957  Τα νέα πρόσωπα στις κοινοβουλευτικές ομάδες τη...
# 1958  Συγχαρητήριο μήνυμα State Department στη νέα κ...
# 1959  Γιώργος Ζαββός, ο νέος Υφυπουργός αρμόδιος για...
#
#                    Datetime  \
# 0     09 Ιουλίου 2022 08:17
# 1     08 Ιουλίου 2022 11:54
# 2     08 Ιουλίου 2022 09:41
# 3     08 Ιουλίου 2022 06:15
# 4     07 Ιουλίου 2022 22:01
# ...                     ...
# 1955  09 Ιουλίου 2019 07:17
# 1956  09 Ιουλίου 2019 07:11
# ...

# %%
nea_doc.dtypes
# Out:
# Title               object
# Datetime            object
# Href                object
# Leadtext            object
# Tag                 object
# Year                object
# Month               object
# Day                 object
# Time                object
# Date        datetime64[ns]
# dtype: object

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
nea_doc.to_csv("/content/gdrive/My Drive/Colab Notebooks/nea-dimokratia.tsv", sep='\t')

# %%
import base64
from IPython.display import HTML

def create_download_link( df, title = "Download CSV file", filename = "data.csv"):
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(nea_doc, filename='nea-dimokratia.tsv')
# Out:
# <a download="nea-dimokratia.tsv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
